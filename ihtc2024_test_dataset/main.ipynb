# %%
import os
import json

def read_all_json_files(directory):
    json_files_data = []
    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
                json_files_data.append(data)
    return json_files_data

# Example usage
directory_path = 'ihtc2024_test_dataset'
all_json_data_test = read_all_json_files(directory_path)
print(all_json_data_test)
# Out:
# [{'days': 14, 'skill_levels': 3, 'shift_types': ['early', 'late', 'night'], 'age_groups': ['infant', 'adult', 'elderly'], 'occupants': [{'id': 'a0', 'gender': 'B', 'age_group': 'adult', 'length_of_stay': 4, 'workload_produced': [2, 1, 1, 3, 1, 1, 1, 2, 1, 2, 1, 1], 'skill_level_required': [2, 2, 1, 0, 2, 0, 2, 1, 0, 2, 0, 0], 'room_id': 'r2'}, {'id': 'a1', 'gender': 'A', 'age_group': 'adult', 'length_of_stay': 3, 'workload_produced': [2, 3, 1, 3, 2, 1, 1, 3, 1], 'skill_level_required': [2, 2, 0, 0, 0, 0, 2, 0, 0], 'room_id': 'r3'}, {'id': 'a2', 'gender': 'A', 'age_group': 'elderly', 'length_of_stay': 2, 'workload_produced': [3, 2, 1, 1, 1, 1], 'skill_level_required': [2, 2, 0, 1, 2, 0], 'room_id': 'r4'}, {'id': 'a3', 'gender': 'A', 'age_group': 'elderly', 'length_of_stay': 4, 'workload_produced': [2, 2, 1, 1, 2, 1, 1, 3, 1, 2, 3, 1], 'skill_level_required': [0, 1, 1, 0, 0, 0, 0, 0, 1, 1, 0, 1], 'room_id': 'r0'}, {'id': 'a4', 'gender': 'B', 'age_group': 'elderly', 'length_of_stay': 1, 'workload_produced': [1, 1, 1], 'skill_level_required': [1, 2, 0], 'room_id': 'r5'}], 'patients': [{'id': 'p00', 'mandatory': False, 'gender': 'A', 'age_group': 'adult', 'length_of_stay': 5, 'surgery_release_day': 1, 'surgery_duration': 90, 'surgeon_id': 's1', 'incompatible_room_ids': [], 'workload_produced': [3, 2, 2, 3, 2, 2, 2, 2, 1, 2, 2, 1, 2, 1, 2], 'skill_level_required': [2, 1, 0, 2, 2, 0, 0, 0, 0, 2, 0, 0, 1, 1, 0]}, {'id': 'p01', 'mandatory': False, 'gender': 'B', 'age_group': 'adult', 'length_of_stay': 9, 'surgery_release_day': 1, 'surgery_duration': 300, 'surgeon_id': 's1', 'incompatible_room_ids': ['r2', 'r5'], 'workload_produced': [2, 3, 2, 3, 2, 1, 2, 3, 2, 2, 2, 2, 3, 2, 2, 2, 2, 1, 3, 2, 1, 2, 1, 2, 3, 1, 1], 'skill_level_required': [0, 2, 0, 1, 1, 0, 2, 0, 0, 0, 2, 1, 2, 1, 0, 1, 1, 1, 1, 1, 1, 2, 2, 1, 2, 1, 0]}, {'id': 'p02', 'mandatory': False, 'gender': 'B', 'age_group': 'elderly', 'length_of_stay': 5, 'surgery_release_day': 2, 'surgery_duration': 120, 'surgeon_id': 's1', 'incompatible_room_ids': ['r4'], 'workload_produced': [3, 2, 2, 2, 2, 2, 2, 3, 2, 3, 3, 2, 2, 3, 2], 'skill_level_required': [0, 1, 0, 1, 2, 0, 2, 1, 0, 2, 0, 1, 2, 2, 0]}, {'id': 'p03', 'mandatory': True, 'gender': 'A', 'age_group': 'elderly', 'length_of_stay': 8, 'surgery_release_day': 1, 'surgery_due_day': 12, 'surgery_duration': 300, 'surgeon_id': 's0', 'incompatible_room_ids': [], 'workload_produced': [2, 3, 2, 2, 2, 2, 2, 3, 1, 2, 3, 1, 3, 2, 1, 3, 3, 1, 2, 3, 2, 1, 2, 1], 'skill_level_required': [2, 1, 0, 2, 2, 0, 2, 1, 1, 2, 0, 1, 1, 1, 0, 1, 2, 1, 0, 1, 1, 0, 2, 0]}, {'id': 'p04', 'mandatory': False, 'gender': 'B', 'age_group': 'elderly', 'length_of_stay': 5, 'surgery_release_day': 2, 'surgery_duration': 90, 'surgeon_id': 's1', 'incompatible_room_ids': ['r3', 'r4'], 'workload_produced': [3, 2, 1, 2, 2, 1, 3, 2, 2, 2, 3, 1, 1, 1, 2], 'skill_level_required': [2, 1, 1, 1, 0, 0, 0, 1, 0, 1, 0, 0, 1, 0, 1]}, {'id': 'p05', 'mandatory': True, 'gender': 'B', 'age_group': 'elderly', 'length_of_stay': 8, 'surgery_release_day': 3, 'surgery_due_day': 9, 'surgery_duration': 180, 'surgeon_id': 's0', 'incompatible_room_ids': [], 'workload_produced': [3, 2, 1, 3, 2, 2, 3, 2, 2, 2, 2, 2, 2, 3, 1, 3, 2, 1, 1, 1, 1, 1, 2, 2], 'skill_level_required': [1, 0, 0, 2, 0, 1, 0, 2, 0, 1, 0, 0, 0, 0, 0, 0, 2, 0, 0, 1, 0, 0, 2, 0]}, {'id': 'p06', 'mandatory': False, 'gender': 'B', 'age_group': 'adult', 'length_of_stay': 4, 'surgery_release_day': 7, 'surgery_duration': 240, 'surgeon_id': 's1', 'incompatible_room_ids': ['r2'], 'workload_produced': [2, 2, 2, 2, 2, 1, 2, 2, 2, 3, 2, 2], 'skill_level_required': [1, 2, 0, 1, 0, 0, 1, 2, 0, 1, 2, 0]}, {'id': 'p07', 'mandatory': False, 'gender': 'B', 'age_group': 'elderly', 'length_of_stay': 6, 'surgery_release_day': 3, 'surgery_duration': 90, 'surgeon_id': 's0', 'incompatible_room_ids': [], 'workload_produced': [2, 2, 1, 3, 2, 2, 3, 2, 1, 2, 2, 2, 2, 3, 2, 3, 2, 2], 'skill_level_required': [2, 0, 0, 0, 2, 0, 2, 2, 1, 0, 1, 0, 1, 1, 0, ...

# %%
all_json_data_test[3]
# Out:
# {'patients': [{'id': 'p00',
#    'admission_day': 3,
#    'room': 'r3',
#    'operating_theater': 't0'},
#   {'id': 'p01', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p02', 'admission_day': 'none'},
#   {'id': 'p03', 'admission_day': 1, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p04', 'admission_day': 13, 'room': 'r3', 'operating_theater': 't0'},
#   {'id': 'p05', 'admission_day': 'none'},
#   {'id': 'p06', 'admission_day': 'none'},
#   {'id': 'p07', 'admission_day': 'none'},
#   {'id': 'p08', 'admission_day': 'none'},
#   {'id': 'p09', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p10', 'admission_day': 3, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p11', 'admission_day': 'none'},
#   {'id': 'p12', 'admission_day': 'none'},
#   {'id': 'p13', 'admission_day': 'none'},
#   {'id': 'p14', 'admission_day': 'none'},
#   {'id': 'p15', 'admission_day': 4, 'room': 'r3', 'operating_theater': 't0'},
#   {'id': 'p16', 'admission_day': 1, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p17', 'admission_day': 'none'},
#   {'id': 'p18', 'admission_day': 7, 'room': 'r4', 'operating_theater': 't1'},
#   {'id': 'p19', 'admission_day': 'none'},
#   {'id': 'p20', 'admission_day': 9, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p21', 'admission_day': 'none'},
#   {'id': 'p22', 'admission_day': 'none'},
#   {'id': 'p23', 'admission_day': 'none'},
#   {'id': 'p24', 'admission_day': 4, 'room': 'r1', 'operating_theater': 't0'},
#   {'id': 'p25', 'admission_day': 'none'},
#   {'id': 'p26', 'admission_day': 'none'},
#   {'id': 'p27', 'admission_day': 'none'},
#   {'id': 'p28', 'admission_day': 'none'},
#   {'id': 'p29', 'admission_day': 10, 'room': 'r0', 'operating_theater': 't0'},
#   {'id': 'p30', 'admission_day': 'none'},
#   {'id': 'p31', 'admission_day': 'none'},
#   {'id': 'p32', 'admission_day': 'none'},
#   {'id': 'p33', 'admission_day': 'none'},
#   {'id': 'p34', 'admission_day': 'none'},
#   {'id': 'p35', 'admission_day': 'none'},
#   {'id': 'p36', 'admission_day': 'none'},
#   {'id': 'p37', 'admission_day': 4, 'room': 'r3', 'operating_theater': 't0'},
#   {'id': 'p38', 'admission_day': 8, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p39', 'admission_day': 'none'},
#   {'id': 'p40', 'admission_day': 3, 'room': 'r0', 'operating_theater': 't0'},
#   {'id': 'p41', 'admission_day': 13, 'room': 'r2', 'operating_theater': 't0'},
#   {'id': 'p42', 'admission_day': 'none'},
#   {'id': 'p43', 'admission_day': 'none'},
#   {'id': 'p44', 'admission_day': 9, 'room': 'r1', 'operating_theater': 't0'},
#   {'id': 'p45', 'admission_day': 9, 'room': 'r1', 'operating_theater': 't0'},
#   {'id': 'p46', 'admission_day': 10, 'room': 'r3', 'operating_theater': 't0'},
#   {'id': 'p47', 'admission_day': 1, 'room': 'r4', 'operating_theater': 't0'},
#   {'id': 'p48', 'admission_day': 1, 'room': 'r4', 'operating_theater': 't0'},
#   {'id': 'p49', 'admission_day': 'none'},
#   {'id': 'p50', 'admission_day': 'none'},
#   {'id': 'p51', 'admission_day': 'none'},
#   {'id': 'p52', 'admission_day': 11, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p53', 'admission_day': 8, 'room': 'r1', 'operating_theater': 't1'},
#   {'id': 'p54', 'admission_day': 'none'},
#   {'id': 'p55', 'admission_day': 'none'},
#   {'id': 'p56', 'admission_day': 13, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p57', 'admission_day': 'none'},
#   {'id': 'p58', 'admission_day': 'none'},
#   {'id': 'p59', 'admission_day': 11, 'room': 'r4', 'operating_theater': 't1'},
#   {'id': 'p60', 'admission_day': 9, 'room': 'r1', 'operating_theater': 't0'},
#   {'id': 'p61', 'admission_day': 'none'}],
#  'nurses': [{'id': 'n00',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r4', 'r5']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 2, 'shift': 'late', 'rooms': ['r0', 'r4']},
#     {'day': 3, 'shift': 'night', 'rooms': ['r0', 'r3', 'r5']},
#     {'day': 4, 'shift': 'night', 'rooms': ['r0', 'r2', 'r3', 'r4', 'r5']},
#     {'day': 6, 'shift': 'night', 'rooms': ['r0', 'r3', 'r5']},
#     {'day': 8, 'shift': 'night', 'rooms': ['r2', 'r3', 'r5']},
#     {'day': 10, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 11, 'shift': 'late', 'rooms': ['r3', 'r4', 'r5']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r4', 'r5']},
#     {'day': 13, 'shift': 'night', 'rooms': ['r3', 'r4']}]},
#   {'id': 'n01',
#    'assignments': [{'day': 0, 'shift': 'night', 'rooms': []},
#     {'day': 2, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 4, 'shift': 'night', 'rooms': ['r1']},
#     {'day': 5, 'shift': 'night', 'rooms': ['r0', 'r1', 'r2', 'r4']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r0', 'r4']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r0', 'r2']},
#     {'day': 10, 'shift': 'early', 'rooms': ['r2', 'r3', 'r4']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r0', 'r3', 'r4']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r3', 'r4']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r0', 'r4']}]},
#   {'id': 'n02',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': []},
#     {'day': 1, 'shift': 'night', 'rooms': []},
#     {'day': 2, 'shift': 'night', 'rooms': []},
#     {'day': 4, 'shift': 'early', 'rooms': ['r1', 'r3']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r1', 'r2', 'r3', 'r4']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r1', 'r2', 'r3']},
#     {'day': 7, 'shift': 'night', 'rooms': ['r0', 'r2', 'r3', 'r4']},
#     {'day': 8, 'shift': 'night', 'rooms': ['r0', 'r1', 'r4']},
#     {'day': 10, 'shift': 'early', 'rooms': ['r0', 'r1']},
#     {'day': 11, 'shift': 'late', 'rooms': ['r0', 'r1']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r0']},
#     {'day': 13, 'shift': 'night', 'rooms': ['r0', 'r1', 'r2', 'r5']}]},
#   {'id': 'n03',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r1', 'r3']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r1', 'r3']},
#     {'day': 2, 'shift': 'night', 'rooms': ['r1', 'r3']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r4']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r2']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r1', 'r2']},
#     {'day': 9, 'shift': 'early', 'rooms': []},
#     {'day': 10, 'shift': 'late', 'rooms': []},
#     {'day': 11, 'shift': 'late', 'rooms': ['r2']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r3']}]},
#   {'id': 'n04',
#    'assignments': [{'day': 0,
#      'shift': 'night',
#      'rooms': ['r0', 'r1', 'r2', 'r3', 'r4', 'r5']},
#     {'day': 1,
#      'shift': 'night',
#      'rooms': ['r0', 'r1', 'r2', 'r3', 'r4', 'r5']},
#     {'day': 2, 'shift': 'night', 'rooms': ['r2', 'r4', 'r5']},
#     {'day': 3, 'shift': 'night', 'rooms': ['r1', 'r2', 'r4']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r1']},
#     {'day': 6, 'shift': 'night', 'rooms': ['r1', 'r2', 'r4']},
#     {'day': 7, 'shift': 'night', 'rooms': []},
#     {'day': 9, 'shift': 'early', 'rooms': ['r1', 'r4']},
#     {'day': 10, 'shift': 'late', 'rooms': ['r1', 'r2', 'r3', 'r4']},
#     {'day': 11, 'shift': 'night', 'rooms': ['r1', 'r3']},
#     {'day': 12, 'shift': 'night', 'rooms': ['r1', 'r3']}]},
#   {'id': 'n05',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r0', 'r2']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r2', 'r3', 'r4']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r3', 'r5']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r3', 'r5']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r3', 'r5']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r1', 'r3', 'r5']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r3', 'r5']},
#     {'day': 10, 'shift': 'late', 'rooms': ['r0', 'r5']},
#     {'day': 11, 'shift': 'night', 'rooms': ['r0', 'r2', 'r4', 'r5']},
#     {'day': 12, 'shift': 'night', 'rooms': ['r0', 'r2', 'r4', 'r5']}]},
#   {'id': 'n06',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 2, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r0', 'r1', 'r5']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r0', 'r2', 'r5']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r0']},
#     {'day': 7, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 9, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r1']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r1', 'r2']},
#     {'day': 13, 'shift': 'late', 'rooms': ['r1', 'r2']}]},
#   {'id': 'n07',
#    'assignments': [{'day': 1, 'shift': 'early', 'rooms': ['r2', 'r3', 'r5']},
#     {'day': 2, 'shift': 'late', 'rooms': ['r2', 'r3', 'r5']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r3', 'r5']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r3']},
#     {'day': 5, 'shift': 'night', 'rooms': ['r3', 'r5']},
#     {'day': 7, 'shift': 'late', 'rooms': ['r0', 'r2', 'r3', 'r4', 'r5']},
#     {'day': 8, 'shift': 'late', 'rooms': ['r0', 'r3', 'r4', 'r5']},
#     {'day': 9, 'shift': 'late', 'rooms': ['r0', 'r2', 'r3', 'r5']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r0', 'r2', 'r4', 'r5']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r0', 'r5']},
#     {'day': 13, 'shift': 'late', 'rooms': ['r0', 'r4', 'r5']}]},
#   {'id': 'n08',
#    'assignments': [{'day': 1, 'shift': 'early', 'rooms': []},
#     {'day': 2, 'shift': 'night', 'rooms': ['r0']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r2', 'r5']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 8, 'shift': 'early', 'rooms': []},
#     {'day': 9, 'shift': 'late', 'rooms': ['r4']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r3']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r2', 'r3']}]},
#   {'id': 'n09',
#    'assignments': [{'day': 0,
#      'shift': 'early',
#      'rooms': ['r0', 'r1', 'r2', 'r3', 'r4']},
#     {'day': 1, 'shift': 'early', 'rooms': ['r0', 'r1', 'r4']},
#     {'day': 2, 'shift': 'early', 'rooms': ['r1', 'r2', 'r3', 'r4']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r0', 'r1', 'r4']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r0', 'r1', 'r4']},
#     {'day': 7, 'shift': 'late', 'rooms': []},
#     {'day': 9, 'shift': 'night', 'rooms': ['r1', 'r3', 'r4']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r1']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r1']}]},
#   {'id': 'n10',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': []},
#     {'day': 2, 'shift': 'early', 'rooms': ['r0']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r0', 'r4']},
#     {'day': 7, 'shift': 'night', 'rooms': ['r1', 'r5']},
#     {'day': 9, 'shift': 'night', 'rooms': ['r5']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r2', 'r5']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r5']}]},
#   {'id': 'n11',
#    'assignments': [{'day': 3, 'shift': 'late', 'rooms': []},
#     {'day': 5, 'shift': 'early', 'rooms': []},
#     {'day': 6, 'shift': 'late', 'rooms': []},
#     {'day': 7, 'shift': 'night', 'rooms': []},
#     {'day': 9, 'shift': 'night', 'rooms': ['r0', 'r2']},
#     {'day': 13, 'shift': 'early', 'rooms': []}]},
#   {'id': 'n12',
#    'assignments': [{'day': 3, 'shift': 'early', 'rooms': []},
#     {'day': 6, 'shift': 'late', 'rooms': []},
#     {'day': 8, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 9, 'shift': 'night', 'rooms': []},
#     {'day': 13, 'shift': 'early', 'rooms': ['r1', 'r2']}]},
#   {'id': 'n13',
#    'assignments': [{'day': 3, 'shift': 'early', 'rooms': []},
#     {'day': 8, 'shift': 'late', 'rooms': ['r2']},
#     {'day': 13, 'shift': 'late', 'rooms': ['r3']}]},
#   {'id': 'n14', 'assignments': [{'day': 8, 'shift': 'late', 'rooms': []}]}],
#  'costs': ['Cost: 15713, Unscheduled: 14400,  Delay: 275,  OpenOT: 270,  AgeMix: 5,  Skill: 32,  Excess: 6,  Continuity: 725,  SurgeonTransfer: 0']}

# %%
def read_all_json_files(directory):
    json_files_data = []
    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
                json_files_data.append(data)
    return json_files_data

# Example usage
directory_path = '../ihtc2024_test_solutions/ihtc2024_test_solutions'
all_json_data_sol = read_all_json_files(directory_path)
print(all_json_data_sol)
# Out:
# [{'patients': [{'id': 'p00', 'admission_day': 3, 'room': 'r3', 'operating_theater': 't1'}, {'id': 'p01', 'admission_day': 3, 'room': 'r2', 'operating_theater': 't1'}, {'id': 'p02', 'admission_day': 17, 'room': 'r0', 'operating_theater': 't0'}, {'id': 'p03', 'admission_day': 19, 'room': 'r2', 'operating_theater': 't0'}, {'id': 'p04', 'admission_day': 8, 'room': 'r4', 'operating_theater': 't0'}, {'id': 'p05', 'admission_day': 1, 'room': 'r2', 'operating_theater': 't1'}, {'id': 'p06', 'admission_day': 17, 'room': 'r0', 'operating_theater': 't0'}, {'id': 'p07', 'admission_day': 'none'}, {'id': 'p08', 'admission_day': 'none'}, {'id': 'p09', 'admission_day': 'none'}, {'id': 'p10', 'admission_day': 16, 'room': 'r4', 'operating_theater': 't1'}, {'id': 'p11', 'admission_day': 13, 'room': 'r0', 'operating_theater': 't1'}, {'id': 'p12', 'admission_day': 4, 'room': 'r3', 'operating_theater': 't0'}, {'id': 'p13', 'admission_day': 11, 'room': 'r2', 'operating_theater': 't0'}, {'id': 'p14', 'admission_day': 'none'}, {'id': 'p15', 'admission_day': 19, 'room': 'r2', 'operating_theater': 't0'}, {'id': 'p16', 'admission_day': 3, 'room': 'r0', 'operating_theater': 't1'}, {'id': 'p17', 'admission_day': 'none'}, {'id': 'p18', 'admission_day': 8, 'room': 'r4', 'operating_theater': 't0'}, {'id': 'p19', 'admission_day': 1, 'room': 'r4', 'operating_theater': 't1'}, {'id': 'p20', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't0'}, {'id': 'p21', 'admission_day': 3, 'room': 'r1', 'operating_theater': 't1'}, {'id': 'p22', 'admission_day': 16, 'room': 'r4', 'operating_theater': 't1'}, {'id': 'p23', 'admission_day': 'none'}, {'id': 'p24', 'admission_day': 11, 'room': 'r1', 'operating_theater': 't0'}, {'id': 'p25', 'admission_day': 13, 'room': 'r2', 'operating_theater': 't1'}, {'id': 'p26', 'admission_day': 19, 'room': 'r3', 'operating_theater': 't0'}, {'id': 'p27', 'admission_day': 7, 'room': 'r1', 'operating_theater': 't0'}, {'id': 'p28', 'admission_day': 17, 'room': 'r3', 'operating_theater': 't0'}, {'id': 'p29', 'admission_day': 14, 'room': 'r4', 'operating_theater': 't0'}, {'id': 'p30', 'admission_day': 14, 'room': 'r2', 'operating_theater': 't0'}, {'id': 'p31', 'admission_day': 14, 'room': 'r4', 'operating_theater': 't0'}, {'id': 'p32', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't0'}, {'id': 'p33', 'admission_day': 11, 'room': 'r2', 'operating_theater': 't0'}, {'id': 'p34', 'admission_day': 'none'}, {'id': 'p35', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't0'}, {'id': 'p36', 'admission_day': 14, 'room': 'r1', 'operating_theater': 't0'}, {'id': 'p37', 'admission_day': 7, 'room': 'r3', 'operating_theater': 't0'}, {'id': 'p38', 'admission_day': 'none'}, {'id': 'p39', 'admission_day': 4, 'room': 'r3', 'operating_theater': 't0'}, {'id': 'p40', 'admission_day': 1, 'room': 'r2', 'operating_theater': 't1'}, {'id': 'p41', 'admission_day': 13, 'room': 'r0', 'operating_theater': 't1'}], 'nurses': [{'id': 'n00', 'assignments': [{'day': 0, 'shift': 'late', 'rooms': []}, {'day': 1, 'shift': 'late', 'rooms': []}, {'day': 2, 'shift': 'night', 'rooms': []}, {'day': 4, 'shift': 'night', 'rooms': ['r3']}, {'day': 5, 'shift': 'night', 'rooms': ['r3']}, {'day': 7, 'shift': 'night', 'rooms': ['r3', 'r4']}, {'day': 9, 'shift': 'early', 'rooms': ['r3', 'r4']}, {'day': 10, 'shift': 'early', 'rooms': ['r2', 'r3', 'r4']}, {'day': 11, 'shift': 'early', 'rooms': ['r2']}, {'day': 12, 'shift': 'early', 'rooms': ['r2', 'r3', 'r4']}, {'day': 13, 'shift': 'early', 'rooms': ['r2', 'r4']}, {'day': 14, 'shift': 'early', 'rooms': ['r1', 'r2', 'r4']}, {'day': 15, 'shift': 'early', 'rooms': ['r1', 'r4']}, {'day': 16, 'shift': 'late', 'rooms': ['r1', 'r2']}, {'day': 17, 'shift': 'late', 'rooms': ['r1', 'r2', 'r3']}, {'day': 18, 'shift': 'late', 'rooms': ['r3']}, {'day': 19, 'shift': 'late', 'rooms': ['r1', 'r2', 'r3']}, {'day': 20, 'shift': 'late', 'rooms': ['r2', 'r3']}]}, {'id': 'n01', 'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r1', 'r3']}, {'d ...

# %%
all_json_data_sol[1]
# Out:
# {'patients': [{'id': 'p00', 'admission_day': 'none'},
#   {'id': 'p01', 'admission_day': 4, 'room': 'r1', 'operating_theater': 't1'},
#   {'id': 'p02', 'admission_day': 4, 'room': 'r1', 'operating_theater': 't0'},
#   {'id': 'p03', 'admission_day': 4, 'room': 'r0', 'operating_theater': 't0'},
#   {'id': 'p04', 'admission_day': 9, 'room': 'r3', 'operating_theater': 't1'},
#   {'id': 'p05', 'admission_day': 9, 'room': 'r2', 'operating_theater': 't1'},
#   {'id': 'p06', 'admission_day': 'none'},
#   {'id': 'p07', 'admission_day': 3, 'room': 'r6', 'operating_theater': 't2'},
#   {'id': 'p08', 'admission_day': 3, 'room': 'r1', 'operating_theater': 't2'},
#   {'id': 'p09', 'admission_day': 1, 'room': 'r3', 'operating_theater': 't0'},
#   {'id': 'p10', 'admission_day': 13, 'room': 'r4', 'operating_theater': 't2'},
#   {'id': 'p11', 'admission_day': 1, 'room': 'r4', 'operating_theater': 't0'},
#   {'id': 'p12', 'admission_day': 12, 'room': 'r7', 'operating_theater': 't2'},
#   {'id': 'p13', 'admission_day': 2, 'room': 'r4', 'operating_theater': 't1'},
#   {'id': 'p14', 'admission_day': 7, 'room': 'r6', 'operating_theater': 't1'},
#   {'id': 'p15', 'admission_day': 9, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p16', 'admission_day': 7, 'room': 'r7', 'operating_theater': 't1'},
#   {'id': 'p17', 'admission_day': 3, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p18', 'admission_day': 7, 'room': 'r3', 'operating_theater': 't1'},
#   {'id': 'p19', 'admission_day': 11, 'room': 'r0', 'operating_theater': 't2'},
#   {'id': 'p20', 'admission_day': 11, 'room': 'r1', 'operating_theater': 't2'},
#   {'id': 'p21', 'admission_day': 2, 'room': 'r4', 'operating_theater': 't1'},
#   {'id': 'p22', 'admission_day': 7, 'room': 'r6', 'operating_theater': 't1'},
#   {'id': 'p23', 'admission_day': 11, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p24', 'admission_day': 7, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p25', 'admission_day': 9, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p26', 'admission_day': 2, 'room': 'r6', 'operating_theater': 't1'},
#   {'id': 'p27', 'admission_day': 2, 'room': 'r5', 'operating_theater': 't2'},
#   {'id': 'p28', 'admission_day': 3, 'room': 'r6', 'operating_theater': 't1'},
#   {'id': 'p29', 'admission_day': 3, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p30', 'admission_day': 12, 'room': 'r7', 'operating_theater': 't2'},
#   {'id': 'p31', 'admission_day': 7, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p32', 'admission_day': 8, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p33', 'admission_day': 11, 'room': 'r1', 'operating_theater': 't1'},
#   {'id': 'p34', 'admission_day': 1, 'room': 'r0', 'operating_theater': 't0'},
#   {'id': 'p35', 'admission_day': 3, 'room': 'r2', 'operating_theater': 't1'},
#   {'id': 'p36', 'admission_day': 3, 'room': 'r6', 'operating_theater': 't1'},
#   {'id': 'p37', 'admission_day': 2, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p38', 'admission_day': 7, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p39', 'admission_day': 4, 'room': 'r0', 'operating_theater': 't0'},
#   {'id': 'p40', 'admission_day': 1, 'room': 'r7', 'operating_theater': 't0'},
#   {'id': 'p41', 'admission_day': 13, 'room': 'r4', 'operating_theater': 't2'},
#   {'id': 'p42', 'admission_day': 4, 'room': 'r5', 'operating_theater': 't0'},
#   {'id': 'p43', 'admission_day': 7, 'room': 'r5', 'operating_theater': 't1'},
#   {'id': 'p44', 'admission_day': 11, 'room': 'r6', 'operating_theater': 't2'},
#   {'id': 'p45', 'admission_day': 4, 'room': 'r3', 'operating_theater': 't1'},
#   {'id': 'p46', 'admission_day': 8, 'room': 'r2', 'operating_theater': 't1'},
#   {'id': 'p47', 'admission_day': 3, 'room': 'r0', 'operating_theater': 't1'},
#   {'id': 'p48', 'admission_day': 12, 'room': 'r0', 'operating_theater': 't2'},
#   {'id': 'p49', 'admission_day': 2, 'room': 'r2', 'operating_theater': 't2'},
#   {'id': 'p50', 'admission_day': 13, 'room': 'r5', 'operating_theater': 't2'},
#   {'id': 'p51', 'admission_day': 4, 'room': 'r4', 'operating_theater': 't0'},
#   {'id': 'p52', 'admission_day': 2, 'room': 'r7', 'operating_theater': 't2'},
#   {'id': 'p53', 'admission_day': 13, 'room': 'r1', 'operating_theater': 't2'}],
#  'nurses': [{'id': 'n00',
#    'assignments': [{'day': 0, 'shift': 'night', 'rooms': ['r7']},
#     {'day': 2, 'shift': 'early', 'rooms': ['r7']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r4']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r1', 'r4']},
#     {'day': 5, 'shift': 'night', 'rooms': ['r1', 'r3', 'r4', 'r7']},
#     {'day': 7, 'shift': 'night', 'rooms': ['r1', 'r3', 'r4']},
#     {'day': 9, 'shift': 'night', 'rooms': ['r4']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r1']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r0', 'r1', 'r4', 'r6', 'r7']},
#     {'day': 13, 'shift': 'late', 'rooms': ['r0', 'r6', 'r7']}]},
#   {'id': 'n01',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r2']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r2', 'r5']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r7']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r0']},
#     {'day': 6, 'shift': 'night', 'rooms': ['r7']},
#     {'day': 7, 'shift': 'night', 'rooms': ['r2', 'r6']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r0']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r3', 'r6']},
#     {'day': 12, 'shift': 'early', 'rooms': []},
#     {'day': 13, 'shift': 'early', 'rooms': ['r3']}]},
#   {'id': 'n02',
#    'assignments': [{'day': 0,
#      'shift': 'night',
#      'rooms': ['r1', 'r3', 'r5', 'r6']},
#     {'day': 1, 'shift': 'night', 'rooms': ['r2', 'r3', 'r6', 'r7']},
#     {'day': 2, 'shift': 'night', 'rooms': ['r2', 'r3', 'r4', 'r5']},
#     {'day': 3, 'shift': 'night', 'rooms': ['r2', 'r3', 'r4', 'r5', 'r7']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r4', 'r5', 'r7']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r2', 'r4', 'r5']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r3', 'r4', 'r6', 'r7']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r1', 'r6']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r4', 'r7']},
#     {'day': 10, 'shift': 'late', 'rooms': ['r0', 'r6']},
#     {'day': 11, 'shift': 'night', 'rooms': ['r0', 'r1', 'r3', 'r6', 'r7']},
#     {'day': 12, 'shift': 'night', 'rooms': ['r0', 'r2', 'r3', 'r4', 'r6']},
#     {'day': 13, 'shift': 'night', 'rooms': ['r0', 'r1', 'r2', 'r3', 'r6']}]},
#   {'id': 'n03',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': []},
#     {'day': 1, 'shift': 'late', 'rooms': []},
#     {'day': 2, 'shift': 'late', 'rooms': []},
#     {'day': 3, 'shift': 'late', 'rooms': ['r3']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r2']},
#     {'day': 6, 'shift': 'early', 'rooms': []},
#     {'day': 7, 'shift': 'early', 'rooms': ['r2']},
#     {'day': 8, 'shift': 'late', 'rooms': []},
#     {'day': 10, 'shift': 'early', 'rooms': ['r1', 'r2']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r2']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r2']}]},
#   {'id': 'n04',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r0', 'r1', 'r7']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r0', 'r1']},
#     {'day': 2, 'shift': 'night', 'rooms': ['r0', 'r1']},
#     {'day': 3, 'shift': 'night', 'rooms': ['r0', 'r1', 'r6']},
#     {'day': 4, 'shift': 'night', 'rooms': ['r0', 'r1']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r1', 'r6']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r0', 'r1']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r0']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r2', 'r6']},
#     {'day': 10, 'shift': 'early', 'rooms': ['r0', 'r3']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r3', 'r4', 'r6', 'r7']},
#     {'day': 12, 'shift': 'early', 'rooms': ['r3', 'r5']}]},
#   {'id': 'n05',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r6', 'r7']},
#     {'day': 2, 'shift': 'night', 'rooms': ['r6', 'r7']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r3']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r0', 'r6']},
#     {'day': 6, 'shift': 'early', 'rooms': ['r0', 'r3', 'r7']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r7']},
#     {'day': 9, 'shift': 'late', 'rooms': ['r0', 'r4', 'r7']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r0', 'r4', 'r7']},
#     {'day': 11, 'shift': 'night', 'rooms': ['r4']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r4']}]},
#   {'id': 'n06',
#    'assignments': [{'day': 0, 'shift': 'late', 'rooms': ['r3', 'r4', 'r6']},
#     {'day': 1, 'shift': 'late', 'rooms': ['r3', 'r4']},
#     {'day': 2, 'shift': 'late', 'rooms': ['r0', 'r1', 'r3', 'r6']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r1', 'r6']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r0', 'r3']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r5', 'r7']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r4', 'r5', 'r7']},
#     {'day': 7, 'shift': 'night', 'rooms': ['r0', 'r5', 'r7']},
#     {'day': 9, 'shift': 'late', 'rooms': ['r3', 'r6']},
#     {'day': 10, 'shift': 'late', 'rooms': []},
#     {'day': 11, 'shift': 'late', 'rooms': ['r3', 'r5']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r5', 'r7']},
#     {'day': 13, 'shift': 'night', 'rooms': ['r4', 'r5', 'r7']}]},
#   {'id': 'n07',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': ['r0', 'r7']},
#     {'day': 1, 'shift': 'early', 'rooms': []},
#     {'day': 2, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 3, 'shift': 'late', 'rooms': []},
#     {'day': 4, 'shift': 'late', 'rooms': ['r5']},
#     {'day': 5, 'shift': 'night', 'rooms': ['r5']},
#     {'day': 6, 'shift': 'night', 'rooms': []},
#     {'day': 7, 'shift': 'night', 'rooms': []},
#     {'day': 9, 'shift': 'early', 'rooms': []},
#     {'day': 10, 'shift': 'early', 'rooms': ['r4']},
#     {'day': 11, 'shift': 'early', 'rooms': []},
#     {'day': 12, 'shift': 'late', 'rooms': []},
#     {'day': 13, 'shift': 'late', 'rooms': []}]},
#   {'id': 'n08',
#    'assignments': [{'day': 0, 'shift': 'night', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 1, 'shift': 'night', 'rooms': ['r0', 'r4']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r0']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r0', 'r4']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r0', 'r3']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r2', 'r3']},
#     {'day': 9, 'shift': 'early', 'rooms': ['r1', 'r3', 'r5']},
#     {'day': 10, 'shift': 'late', 'rooms': ['r2', 'r3', 'r5']},
#     {'day': 11, 'shift': 'night', 'rooms': ['r2', 'r5']},
#     {'day': 13, 'shift': 'late', 'rooms': ['r2', 'r3', 'r5']}]},
#   {'id': 'n09',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': []},
#     {'day': 1, 'shift': 'night', 'rooms': ['r1']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r1', 'r2']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r2', 'r6']},
#     {'day': 5, 'shift': 'early', 'rooms': ['r1', 'r3']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r1', 'r6']},
#     {'day': 7, 'shift': 'late', 'rooms': ['r5', 'r7']},
#     {'day': 8, 'shift': 'late', 'rooms': ['r0']},
#     {'day': 9, 'shift': 'night', 'rooms': ['r2', 'r5', 'r7']},
#     {'day': 10, 'shift': 'night', 'rooms': ['r1', 'r2', 'r5']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r1', 'r5']}]},
#   {'id': 'n10',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': []},
#     {'day': 1, 'shift': 'night', 'rooms': ['r5']},
#     {'day': 3, 'shift': 'early', 'rooms': ['r7']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r2', 'r7']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r2', 'r3']},
#     {'day': 6, 'shift': 'late', 'rooms': ['r2']},
#     {'day': 8, 'shift': 'early', 'rooms': []},
#     {'day': 9, 'shift': 'late', 'rooms': ['r1']},
#     {'day': 10, 'shift': 'late', 'rooms': ['r1', 'r4', 'r7']},
#     {'day': 12, 'shift': 'early', 'rooms': []},
#     {'day': 13, 'shift': 'night', 'rooms': []}]},
#   {'id': 'n11',
#    'assignments': [{'day': 1, 'shift': 'early', 'rooms': ['r2', 'r3']},
#     {'day': 2, 'shift': 'early', 'rooms': []},
#     {'day': 3, 'shift': 'early', 'rooms': ['r3', 'r6']},
#     {'day': 4, 'shift': 'late', 'rooms': ['r6']},
#     {'day': 5, 'shift': 'late', 'rooms': ['r4', 'r6']},
#     {'day': 6, 'shift': 'night', 'rooms': ['r1']},
#     {'day': 8, 'shift': 'early', 'rooms': ['r4', 'r5']},
#     {'day': 9, 'shift': 'late', 'rooms': ['r2', 'r5']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r2']}]},
#   {'id': 'n12',
#    'assignments': [{'day': 1, 'shift': 'early', 'rooms': ['r0', 'r5']},
#     {'day': 2, 'shift': 'early', 'rooms': ['r0', 'r3', 'r4']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r0', 'r4', 'r7']},
#     {'day': 4, 'shift': 'night', 'rooms': ['r2', 'r3', 'r4', 'r7']},
#     {'day': 5, 'shift': 'night', 'rooms': ['r0', 'r2', 'r6']},
#     {'day': 6,
#      'shift': 'night',
#      'rooms': ['r0', 'r2', 'r3', 'r4', 'r5', 'r6']},
#     {'day': 8, 'shift': 'late', 'rooms': ['r3', 'r4', 'r6']},
#     {'day': 9, 'shift': 'night', 'rooms': ['r0', 'r1', 'r3', 'r6']},
#     {'day': 11, 'shift': 'early', 'rooms': ['r0', 'r2']},
#     {'day': 12, 'shift': 'late', 'rooms': ['r0', 'r1', 'r3', 'r4', 'r6']}]},
#   {'id': 'n13',
#    'assignments': [{'day': 0,
#      'shift': 'early',
#      'rooms': ['r1', 'r3', 'r4', 'r5', 'r6']},
#     {'day': 1, 'shift': 'early', 'rooms': ['r1', 'r4', 'r6']},
#     {'day': 2, 'shift': 'early', 'rooms': ['r1', 'r2', 'r5', 'r6']},
#     {'day': 3, 'shift': 'late', 'rooms': ['r2', 'r5']},
#     {'day': 4, 'shift': 'night', 'rooms': ['r5']},
#     {'day': 7, 'shift': 'early', 'rooms': ['r5']},
#     {'day': 9, 'shift': 'night', 'rooms': []},
#     {'day': 11, 'shift': 'late', 'rooms': ['r1', 'r4']},
#     {'day': 12, 'shift': 'night', 'rooms': ['r1', 'r5']}]},
#   {'id': 'n14',
#    'assignments': [{'day': 0, 'shift': 'early', 'rooms': ['r2']},
#     {'day': 2, 'shift': 'early', 'rooms': []},
#     {'day': 3, 'shift': 'night', 'rooms': []},
#     {'day': 4, 'shift': 'night', 'rooms': ['r6']},
#     {'day': 7, 'shift': 'late', 'rooms': []},
#     {'day': 8, 'shift': 'night', 'rooms': ['r1', 'r2', 'r6']},
#     {'day': 10, 'shift': 'early', 'rooms': []},
#     {'day': 11, 'shift': 'late', 'rooms': []},
#     {'day': 12, 'shift': 'night', 'rooms': ['r7']}]},
#   {'id': 'n15',
#    'assignments': [{'day': 1, 'shift': 'early', 'rooms': ['r7']},
#     {'day': 2, 'shift': 'late', 'rooms': ['r7']},
#     {'day': 4, 'shift': 'early', 'rooms': ['r1', 'r5']},
#     {'day': 7, 'shift': 'late', 'rooms': ['r1', 'r3', 'r6']},
#     {'day': 8, 'shift': 'late', 'rooms': ['r1', 'r2', 'r5', 'r7']},
#     {'day': 10, 'shift': 'early', 'rooms': ['r5', 'r6', 'r7']},
#     {'day': 11, 'shift': 'late', 'rooms': ['r0', 'r2', 'r6', 'r7']},
#     {'day': 13, 'shift': 'early', 'rooms': ['r0', 'r6', 'r7']}]},
#   {'id': 'n16',
#    'assignments': [{'day': 2, 'shift': 'late', 'rooms': ['r2', 'r4']},
#     {'day': 7, 'shift': 'late', 'rooms': ['r0', 'r2', 'r4']},
#     {'day': 8, 'shift': 'night', 'rooms': ['r0', 'r3', 'r4']},
#     {'day': 11, 'shift': 'late', 'rooms': []},
#     {'day': 13, 'shift': 'late', 'rooms': ['r1', 'r4']}]},
#   {'id': 'n17', 'assignments': [{'day': 8, 'shift': 'night', 'rooms': []}]},
#   {'id': 'n18',
#    'assignments': [{'day': 8, 'shift': 'night', 'rooms': ['r5', 'r7']}]}],
#  'costs': ['Cost: 2332, Unscheduled: 500,  Delay: 1090,  OpenOT: 150,  AgeMix: 22,  Skill: 195,  Excess: 25,  Continuity: 350,  SurgeonTransfer: 0']}

# %%
#the objective function
# 1. room age mix
# num of days

num_days = all_json_data_test[0]['days']
num_days

num_rooms = len(all_json_data_test[0]['rooms'])

# %%
room_age_mix = [[set() for _ in range(num_rooms)] for _ in range(num_days)]

# %%
# for each patient print print (patient['admission_day'], patient['room']) if not null
i = 0
for patient in all_json_data_sol[0]['patients']:
    if patient['admission_day'] != 'none':
        d = int(patient['admission_day'])
        r = int(patient['room'][1:])
        age = all_json_data_test[0]['patients'][i]['age_group']
        room_age_mix[d][r].add(age)
        print(i, d, r, age)
    i = i+1
# Out:
# 0 3 3 adult
# 1 3 2 adult
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 8
#       6     r = int(patient['room'][1:])
#       7     age = all_json_data_test[0]['patients'][i]['age_group']
# ----> 8     room_age_mix[d][r].add(age)
#       9     print(i, d, r, age)
#      10 i = i+1
#
# IndexError: list index out of range

# %%
# Initialize room_age_mix with sets for each room and day
room_age_mix = [[set() for _ in range(num_rooms)] for _ in range(num_days)]

# Loop through each patient and add their age group to the corresponding room and day
i = 0
for patient in all_json_data_sol[0]['patients']:
    if patient['admission_day'] != 'none':
        d = int(patient['admission_day'])
        r = int(patient['room'][1:])
        
        # Debug prints to check the values of d and r
        print(f"Patient index: {i}, Admission day: {d}, Room: {r}")
        
        # Check if d and r are within the bounds of room_age_mix
        if d < num_days and r < num_rooms:
            age = all_json_data_test[0]['patients'][i]['age_group']
            room_age_mix[d][r].add(age)
            print(i, d, r, age)
        else:
            print(f"Index out of range: day {d}, room {r}")
    i += 1

# Print the resulting room_age_mix
print(room_age_mix)
# Out:
# Patient index: 0, Admission day: 3, Room: 3
# 0 3 3 adult
# Patient index: 1, Admission day: 3, Room: 2
# 1 3 2 adult
# Patient index: 2, Admission day: 17, Room: 0
# Index out of range: day 17, room 0
# Patient index: 3, Admission day: 19, Room: 2
# Index out of range: day 19, room 2
# Patient index: 4, Admission day: 8, Room: 4
# 4 8 4 elderly
# Patient index: 5, Admission day: 1, Room: 2
# 5 1 2 elderly
# Patient index: 6, Admission day: 17, Room: 0
# Index out of range: day 17, room 0
# Patient index: 10, Admission day: 16, Room: 4
# Index out of range: day 16, room 4
# Patient index: 11, Admission day: 13, Room: 0
# 11 13 0 elderly
# Patient index: 12, Admission day: 4, Room: 3
# 12 4 3 adult
# Patient index: 13, Admission day: 11, Room: 2
# 13 11 2 adult
# Patient index: 15, Admission day: 19, Room: 2
# Index out of range: day 19, room 2
# Patient index: 16, Admission day: 3, Room: 0
# 16 3 0 adult
# Patient index: 18, Admission day: 8, Room: 4
# 18 8 4 elderly
# Patient index: 19, Admission day: 1, Room: 4
# 19 1 4 elderly
# Patient index: 20, Admission day: 7, Room: 0
# 20 7 0 elderly
# Patient index: 21, Admission day: 3, Room: 1
# 21 3 1 adult
# Patient index: 22, Admission day: 16, Room: 4
# Index out of range: day 16, room 4
# Patient index: 24, Admission day: 11, Room: 1
# 24 11 1 elderly
# Patient index: 25, Admission day: 13, Room: 2
# 25 13 2 elderly
# Patient index: 26, Admission day: 19, Room: 3
# Index out of range: day 19, room 3
# Patient index: 27, Admission day: 7, Room: 1
# 27 7 1 adult
# Patient index: 28, Admission day: 17, Room: 3
# Index out of range: day 17, room 3
# Patient index: 29, Admission day: 14, Room: 4
# Index out of range: day 14, room 4
# Patient index: 30, Admission day: 14, Room: 2
# Index out of range: day 14, room 2
# Patient index: 31, Admission day: 14, Room: 4
# Index out of range: day 14, room 4
# Patient index: 32, Admission day: 7, Room: 0
# 32 7 0 adult
# Patient index: 33, Admission day: 11, Room: 2
# 33 11 2 elderly
# Patient index: 35, Admission day: 7, Room: 0
# 35 7 0 elderly
# Patient index: 36, Admission day: 14, Room: 1
# Index out of range: day 14, room 1
# Patient index: 37, Admission day: 7, Room: 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 16
#      14 # Check if d and r are within the bounds of room_age_mix
#      15 if d < num_days and r < num_rooms:
# ---> 16     age = all_json_data_test[0]['patients'][i]['age_group']
#      17     room_age_mix[d][r].add(age)
#      18     print(i, d, r, age)
#
# IndexError: list index out of range
